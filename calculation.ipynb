# %%
print(5 // 2)
# Out:
# 2

# %%
import base64

ndjson = """{"timestamp": "2025-08-23T08:48:34Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:35Z", "sensor_type": "temperature", "unit": "°C", "val": 23.6, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:36Z", "sensor_type": "temperature", "unit": "°C", "val": 25.4, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:37Z", "sensor_type": "temperature", "unit": "°C", "val": 23.7, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:38Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}"""

encoded = base64.b64encode(ndjson.encode()).decode()
print(encoded)
# Out:
# ...

# %%
import base64

ndjson = """{"timestamp": "2025-08-23T08:48:44Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:45Z", "sensor_type": "temperature", "unit": "°C", "val": 23.6, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:46Z", "sensor_type": "temperature", "unit": "°C", "val": 25.4, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:47Z", "sensor_type": "temperature", "unit": "°C", "val": 23.7, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:48Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}"""

encoded = base64.b64encode(ndjson.encode()).decode()
print(encoded)
# Out:
# ...

# %%
import base64

ndjson = """{"timestamp": "2025-08-23T08:48:54Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:55Z", "sensor_type": "temperature", "unit": "°C", "val": 23.6, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:56Z", "sensor_type": "temperature", "unit": "°C", "val": 25.4, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:57Z", "sensor_type": "temperature", "unit": "°C", "val": 23.7, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:58Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:54Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:55Z", "sensor_type": "temperature", "unit": "°C", "val": 23.6, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:56Z", "sensor_type": "temperature", "unit": "°C", "val": 25.4, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:57Z", "sensor_type": "temperature", "unit": "°C", "val": 23.7, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:58Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:54Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:55Z", "sensor_type": "temperature", "unit": "°C", "val": 23.6, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:56Z", "sensor_type": "temperature", "unit": "°C", "val": 25.4, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:57Z", "sensor_type": "temperature", "unit": "°C", "val": 23.7, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:58Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:54Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:55Z", "sensor_type": "temperature", "unit": "°C", "val": 23.6, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:56Z", "sensor_type": "temperature", "unit": "°C", "val": 25.4, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:57Z", "sensor_type": "temperature", "unit": "°C", "val": 23.7, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:58Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:54Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:55Z", "sensor_type": "temperature", "unit": "°C", "val": 23.6, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:56Z", "sensor_type": "temperature", "unit": "°C", "val": 25.4, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:57Z", "sensor_type": "temperature", "unit": "°C", "val": 23.7, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:58Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:54Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:55Z", "sensor_type": "temperature", "unit": "°C", "val": 23.6, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:56Z", "sensor_type": "temperature", "unit": "°C", "val": 25.4, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:57Z", "sensor_type": "temperature", "unit": "°C", "val": 23.7, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}
{"timestamp": "2025-08-23T08:48:58Z", "sensor_type": "temperature", "unit": "°C", "val": 25.5, "thing_attributes": {"sensor_id": "temp-001", "zone_id": "b01"}}"""

encoded = base64.b64encode(ndjson.encode()).decode()
print(encoded)
# Out:
# ...

# %%
import base64

ndjson = '''{"timestamp": "2025-08-23T04:35:48Z", "sensor_type": "particle", "unit": "PPM", "val_0_1_um": 1050, "val_0_3_um": 110, "val_0_5_um": 40, "thing_attributes": {"sensor_id": "lpm-005", "zone_id": "b01"}}
{"timestamp": "2025-08-23T04:35:49Z", "sensor_type": "particle", "unit": "PPM", "val_0_1_um": 1000, "val_0_3_um": 100, "val_0_5_um": 35, "thing_attributes": {"sensor_id": "lpm-005", "zone_id": "b01"}}
{"timestamp": "2025-08-23T04:35:50Z", "sensor_type": "particle", "unit": "PPM", "val_0_1_um": 1000, "val_0_3_um": 100, "val_0_5_um": 35, "thing_attributes": {"sensor_id": "lpm-005", "zone_id": "b01"}}
{"timestamp": "2025-08-23T04:35:51Z", "sensor_type": "particle", "unit": "PPM", "val_0_1_um": 1050, "val_0_3_um": 110, "val_0_5_um": 40, "thing_attributes": {"sensor_id": "lpm-005", "zone_id": "b01"}}
{"timestamp": "2025-08-23T04:35:52Z", "sensor_type": "particle", "unit": "PPM", "val_0_1_um": 1050, "val_0_3_um": 110, "val_0_5_um": 40, "thing_attributes": {"sensor_id": "lpm-005", "zone_id": "b01"}}'''

encoded = base64.b64encode(ndjson.encode()).decode()
print(encoded)
# Out:
# ...
